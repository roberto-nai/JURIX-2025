# %% [markdown]
# # LLM-based event detection

# %%
# pip install openai

# %%
# pip install fastapi-poe

# %%
import os
from dotenv import load_dotenv
import openai
import pandas as pd

from src.vars import OUTPUT_DIR, ROOT_DIR
import json
import re
import time
import openpyxl
import ast
import random
from datetime import datetime

# %%
EXECUTE_LLM = False  # to do not waste resources by mistake
EXECUTE_PRELIMINARY_PHASE = False
EXTRACT_PRELIMINARY_SAMPLE = False
EXTRACT_EVALUATION_SAMPLE = False

# %%
df = pd.read_csv(f'{OUTPUT_DIR}/df_complementary_info_filter_dates_keywords_acronims.csv')

# %%
df_llm_output = pd.DataFrame(columns=['case_id', 'output'])
if os.path.exists(f'{OUTPUT_DIR}/df_llm_output.csv'):
    df_llm_output = pd.read_csv(f'{OUTPUT_DIR}/df_llm_output.csv')

if EXECUTE_PRELIMINARY_PHASE:
    df_llm_output = pd.DataFrame(columns=['case_id', 'output'])

df_llm_output
# Out:
#         case_id                                             output
# 0    219-630869  ['[{"event": "DDG n. 36", "date": "31/05/2022"...
# 1    123-350412                                             ['[]']
# 2    153-437453  ['[{"event": "DGC n. 567", "date": "07/07/2022...
# 3    243-697432  ['[{"event": "DD n. 73/2022", "date": "28/10/2...
# 4    035-089020                                             ['[]']
# ..          ...                                                ...
# 595  118-333509                                             ['[]']
# 596  102-284909                                             ['[]']
# 597  114-321551                                             ['[]']
# 598  248-722796                                             ['[]']
# 599  164-467269  ['[{"event": "DD n. 141", "date": "17/12/2021"...
#
# [600 rows x 2 columns]

# %%
def extract_json_objects(text):
    # Pattern to find potential JSON objects (objects and arrays)
    array_pattern = r'(\[[^\[\]]*(\[[^\[\]]*\][^\[\]]*)*\])'

    # Find all potential matches
    assert type(text) == str
    potential_arrays = re.findall(array_pattern, text)

    # Extract just the matched strings
    potential_jsons = [match[0] for match in potential_arrays]

    # Try to parse each potential match
    valid_jsons = []

    for json_str in potential_jsons:
        try:
            # Check if it's valid JSON
            json_obj = json.loads(json_str)
            valid_jsons.append(json_str)
        except json.JSONDecodeError:
            # Skip invalid JSON
            continue

    return [json.dumps(json.loads(obj)) for obj in valid_jsons]

# %%
sys_prompt = ''
with open(f'{ROOT_DIR}/res/prompts/System Prompt.txt', encoding='utf-8') as file:
    sys_prompt = file.read()

# %%
if EXTRACT_PRELIMINARY_SAMPLE:
    idx_sample = df.sample(n=10).case_id
    idx_sample.to_csv(f'{OUTPUT_DIR}/preliminary_evaluation/idx_sample.csv', index=False)
    df = df[df.case_id.isin(idx_sample)]
elif EXECUTE_PRELIMINARY_PHASE:
    idx_sample = pd.read_csv(f'{OUTPUT_DIR}/preliminary_evaluation/idx_sample.csv').case_id
    df = df[df.case_id.isin(idx_sample)]
else:
    df = df.head(600)

# %%
df
# Out:
#         case_id                                 complementary_info
# 0    219-630869  Atto esito di gara: Provvedimento DG n. 36 del...
# 1    123-350412  RUP: dott.ssa Maria Lomboni. Delibera di aggiu...
# 2    153-437453  1) il bando di gara, il fac-simile modulo di o...
# 3    243-697432  Determinazione Agg.ne AD di Marche Multiserviz...
# 4    035-089020  1) La procedura è gestita con il Sistema telem...
# ..          ...                                                ...
# 595  118-333509  Determinazioni a contrarre e di approvazione d...
# 596  102-284909  La ricezione delle richieste di partecipazione...
# 597  114-321551  La procedura di scelta del contraente si svolg...
# 598  248-722796  La presente procedura viene gestita interament...
# 599  164-467269  Appalto indetto con Determinazione della Respo...
#
# [600 rows x 2 columns]

# %%
def run_prompt(user_message: str, model: str):
    time.sleep(3)
    result = dict()

    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": sys_prompt},
            {"role": "user", "content": user_message}],
        stream=True
    )
    result[model] = ''
    for chunk in response:
        if chunk.choices[0].delta.content:
            result[model] += chunk.choices[0].delta.content
    return result

def analyse_instances(df, model, idx):
    executed_caseid = df_llm_output['case_id'].tolist()

    for index, row in df.iterrows():
        if row.case_id in executed_caseid:
            continue
        print(f"Row id: {index}")

        prompt = prompts[idx]
        user_message = prompt % (df[df['case_id'] == row.case_id].iloc[0]['complementary_info'])
        new_row = dict()
        result = run_prompt(user_message, model)

        json_objs = extract_json_objects(result[model])
        if len(json_objs) == 1:
            json_objects = json_objs[0]
        elif len(json_objs) == 0:
            result = run_prompt(user_message, model)
            json_objs = extract_json_objects(result[model])
            if len(json_objs) == 1:
                json_objects = json_objs[0]
            elif len(json_objs) == 0:
                print(f"Error: no json objects found again in instance {index} -> '{row}'")
                continue

        new_row = {"case_id": row.case_id, "output": json_objs}
        df_llm_output.loc[len(df_llm_output)] = new_row

        if index % 5 == 0:
            print(f"TED number {index} / {len(df.index)}...")
            if EXECUTE_PRELIMINARY_PHASE:
                df_llm_output.to_csv(f'{OUTPUT_DIR}/preliminary_evaluation/prompt_{idx}_{model}.csv', index=False)
            else:
                df_llm_output.to_csv(f'{OUTPUT_DIR}/df_llm_output.csv', index=False)

# %% [markdown]
# ## Prompt validation, model selection, execution

# %%
prompts = ["", "", ""]
with open(f'{ROOT_DIR}/res/prompts/prompt1 - zero shot.txt', encoding='utf-8') as file:
    prompts[0] = file.read()

# %%
prompts[1] = ""
with open(f'{ROOT_DIR}/res/prompts/prompt2 - few shot.txt', encoding='utf-8') as file:
    prompts[1] = file.read()

# %%
prompts[2] = ""
with open(f'{ROOT_DIR}/res/prompts/prompt3 - chain of thoughts.txt', encoding='utf-8') as file:
    prompts[2] = file.read()

# %%
if EXECUTE_LLM:
    load_dotenv()
    client = openai.OpenAI(
      api_key=os.getenv('POE_API_KEY'),
      base_url="https://api.poe.com/v1",
    )

    if EXECUTE_PRELIMINARY_PHASE:
        models = ["Llama-3.1-8B", "GPT-4o", "Claude-Sonnet-4"]

        for idx, prompt in enumerate(prompts):
            for model in models:
                print(f"{model} - prompt {idx}")
                analyse_instances(df, model, idx)
    else:
        model = "Claude-Sonnet-4"
        idx = 2
        print(f"{model} - prompt {idx}")
        analyse_instances(df, model, idx)

# %%
df_llm_output
# Out:
#         case_id                                             output
# 0    219-630869  ['[{"event": "DDG n. 36", "date": "31/05/2022"...
# 1    123-350412                                             ['[]']
# 2    153-437453  ['[{"event": "DGC n. 567", "date": "07/07/2022...
# 3    243-697432  ['[{"event": "DD n. 73/2022", "date": "28/10/2...
# 4    035-089020                                             ['[]']
# ..          ...                                                ...
# 595  118-333509                                             ['[]']
# 596  102-284909                                             ['[]']
# 597  114-321551                                             ['[]']
# 598  248-722796                                             ['[]']
# 599  164-467269  ['[{"event": "DD n. 141", "date": "17/12/2021"...
#
# [600 rows x 2 columns]

# %%
print("Correct instances (manual annotation) after the Preliminary Phase:")

print("\nPrompt 0 - Claude-Sonnet-4: 8/10")
print("Prompt 0 - GPT-4o: 7/10")
print("Prompt 0 - Llama-3.1-8B: 2/10")

print("\nPrompt 1 - Claude-Sonnet-4: 7/10")
print("Prompt 1 - GPT-4o: 7/10")
print("Prompt 1 - Llama-3.1-8B: 6/10")

print("\nPrompt 2 - Claude-Sonnet-4: 9/10")
print("Prompt 2 - GPT-4o: 8/10")
print("Prompt 2 - Llama-3.1-8B: 4/10")

print("Chosen combination: Prompt 2 - Claude-Sonnet-4")
# Out:
# Correct instances (manual annotation) after the Preliminary Phase:
#
# Prompt 0 - Claude-Sonnet-4: 8/10
# Prompt 0 - GPT-4o: 7/10
# Prompt 0 - Llama-3.1-8B: 2/10
#
# Prompt 1 - Claude-Sonnet-4: 7/10
# Prompt 1 - GPT-4o: 7/10
# Prompt 1 - Llama-3.1-8B: 6/10
#
# Prompt 2 - Claude-Sonnet-4: 9/10
# Prompt 2 - GPT-4o: 8/10
# Prompt 2 - Llama-3.1-8B: 4/10
# Chosen combination: Prompt 2 - Claude-Sonnet-4

# %% [markdown]
# ## Evaluation

# %%
df_evaluation_temp = df.copy()

# %%
def output_handling(data):
    data = ast.literal_eval(data)
    new_data = []
    for item in data:
        new_data.append(ast.literal_eval(item))
    return new_data

def flatten(xss):
    return [x for xs in xss for x in xs]

def remove_duplicate_dicts(list_of_dicts):
    unique_dicts = []
    seen = set()

    for d in list_of_dicts:
        items = frozenset(d.items())
        if items not in seen:
            seen.add(items)
            unique_dicts.append(d)

    return unique_dicts

def remove_old_dates(list_of_dicts):
    start_of_2016 = datetime(2016, 1, 1)
    filtered_list = []

    for d in list_of_dicts:
        if "date" in d:
            try:
                date_obj = datetime.strptime(d["date"], "%d/%m/%Y")
                if date_obj >= start_of_2016:
                    filtered_list.append(d)
            except ValueError:
                print(f"Warning: Invalid date format in: {d}")
        else:
            print(f"Warning: No 'date' key in: {d}")
    return filtered_list

def is_date_before_2016(italian_date_str):
    try:
        date_obj = datetime.strptime(italian_date_str, "%d/%m/%Y")
        start_of_2016 = datetime(2016, 1, 1)
        return date_obj < start_of_2016

    except ValueError:
        print(f"Error: '{italian_date_str}' is not in the correct format. Use DD/MM/YYYY.")
        return None

# %%
df_llm_output["output"] = df_llm_output["output"].map(output_handling)
df_llm_output["output"] = df_llm_output["output"].map(flatten)
df_llm_output["output"] = df_llm_output["output"].map(remove_duplicate_dicts)
df_llm_output["output"] = df_llm_output["output"].map(remove_old_dates)
df_llm_output
# Out:
# Warning: Invalid date format in: {'event': 'Delibera CdD', 'date': '26/04/22'}
# Warning: Invalid date format in: {'event': 'Delibera CdD', 'date': '28/04/22'}
# Warning: Invalid date format in: {'event': 'Delibera CdD', 'date': '29/04/22'}
# Warning: Invalid date format in: {'event': 'Delibera CdD', 'date': '12/05/22'}
#         case_id                                             output
# 0    219-630869     [{'event': 'DDG n. 36', 'date': '31/05/2022'}]
# 1    123-350412                                                 []
# 2    153-437453    [{'event': 'DGC n. 567', 'date': '07/07/2022'}]
# 3    243-697432  [{'event': 'DD n. 73/2022', 'date': '28/10/202...
# 4    035-089020                                                 []
# ..          ...                                                ...
# 595  118-333509                                                 []
# 596  102-284909                                                 []
# 597  114-321551                                                 []
# 598  248-722796                                                 []
# 599  164-467269     [{'event': 'DD n. 141', 'date': '17/12/2021'}]
#
# [600 rows x 2 columns]

# %%
df_evaluation_temp["event"] = ""
df_evaluation_temp["date"] = ""
df_evaluation_temp["label"] = ""
df_evaluation_temp["note"] = ""
df_evaluation_temp
# Out:
#         case_id                                 complementary_info event date  \
# 0    219-630869  Atto esito di gara: Provvedimento DG n. 36 del...
# 1    123-350412  RUP: dott.ssa Maria Lomboni. Delibera di aggiu...
# 2    153-437453  1) il bando di gara, il fac-simile modulo di o...
# 3    243-697432  Determinazione Agg.ne AD di Marche Multiserviz...
# 4    035-089020  1) La procedura è gestita con il Sistema telem...
# ..          ...                                                ...   ...  ...
# 595  118-333509  Determinazioni a contrarre e di approvazione d...
# 596  102-284909  La ricezione delle richieste di partecipazione...
# 597  114-321551  La procedura di scelta del contraente si svolg...
# 598  248-722796  La presente procedura viene gestita interament...
# 599  164-467269  Appalto indetto con Determinazione della Respo...
#
#     label note
# 0
# 1
# 2
# 3
# 4
# ..    ...  ...
# 595
# 596
# 597
# 598
# 599
#
# [600 rows x 6 columns]

# %%
evaluation = list()
for index, row in df_evaluation_temp.iterrows():
    output = df_llm_output.iloc[index]['output']
    if output == []:
        continue
    if row.case_id == "005-009101":
        print()
    for pair in output:
        if is_date_before_2016(pair["event"]):
            continue
        item = dict()
        item["case_id"] = row.case_id
        item["complementary_info"] = row.complementary_info
        item["event"] = pair["event"]
        item["date"] = pair["date"]
        item["label"] = ""
        item["note"] = ""
        evaluation.append(item)

df_evaluation = pd.DataFrame(evaluation)
#df_evaluation = df_evaluation[~(df_evaluation['date'] > '2016-01-01')]
df_evaluation
# Out:
# Error: 'DDG n. 36' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DGC n. 567' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 73/2022' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 27083' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 10' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Atto del RUP' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/3504' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 40/2022' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 437' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 92' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 1311' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM infrastrutture e trasporti' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Disposizione a Contrarre' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DCC n. 339' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 478' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 128' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 270' is not in the correct format. Use DD/MM/YYYY.
#
# Error: 'Atto n. 2858' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Atto n. 255' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 23409' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 152' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera a contrattare prot. n. 42715' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 500' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 19404' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 830' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD Prot. n. CDG- 0860747-I' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera del C.d.A.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 193' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 115' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 236' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 37' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera ANAC n. 830' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 223' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n.1420' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 14' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 184' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/4149/P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD S.U.A.M n. 282 Reg. Gen' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento di aggiudicazione del Consiglio di Amministrazione del CSI' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2111' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD prot. n. 22249' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM Infrastrutture' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 399' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 156' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2022/86/517' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 176' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DPP n. 125' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 172' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 123' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 12996' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 500' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 134' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n.20007' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 602' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 650' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM delle Infrastrutture e Trasporti' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 20646' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 398' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento n. 111' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 25619' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DGR n. 1276' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 3252' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 177' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 98' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 496' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 225' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/1165' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 1130' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 317' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento n. 794' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 135' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 610' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 170' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 266' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 403' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto del Soggetto Attuatore' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD del 16/06/2022' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/3925/P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento n. 670' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2005' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2072' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD prot. n. 18027' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD-09/816' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD della Direzione 12' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 361' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD Prot. n. CDG- 0860747-I' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. CDG-0290206-Int' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 052' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 221' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 272' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Disposizione a Contrarre' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DPP n. 44' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DPP n. 80' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM del 02/12/2016' is not in the correct format. Use DD/MM/YYYY.
# Error: 'CdG n. 588' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/5964/P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n.1487' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 173' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 176' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 257' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 148' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 16' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 457' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD di ammissione n. 1021' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD di nomina della Commissione Giudicatrice n. 1058' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD di aggiudicazione n. 1118' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 28/2021' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 84' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 22161' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM del 02/12/2016' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 8' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento a contrarre n. 55' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento di aggiudicazione n. 392' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 752' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 930' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 2010' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DGC n. 244' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 138/45' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n.161' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD prot. 24042' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera del C.d.A.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 662' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 874' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM n. 330' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 4' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 29' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 80' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 116' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 1524' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2195' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento di indizione del Consiglio di Amministrazione del CSI' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 342' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento di indizione del Consiglio di Amministrazione del CSI' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 302' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2022/57/0562' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2022/57/0585' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD prot. n.DCFORM.UPCS_FD 26551' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. cron.1472' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 767' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n.739' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/3757' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 218' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Direttiva sull'esecuzione contrattuale dei materiali di commissariato edizione 2017' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 107/2021' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 126/2021' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera ANAC n. 830' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 284' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. cron. 1016' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 918' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 993' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 775' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 1125' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Disposizione a Contrarre' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 102' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 394' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 40 R.U.A.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 841' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 940' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 519' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 269' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2187' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 157' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 728' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. G11792' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD Prot. n. CDG- 0722463-I' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD a contrarre' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 270' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. D12' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 691' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD prot. 12090' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento di indizione del Consiglio di Amministrazione del CSI' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 131' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 232' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1131/2021' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DPP n. 187' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Provvedimento n. 55' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 741' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 780' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 627' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 724' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 765' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD N. 1935' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto di aggiudicazione n. 1' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 590' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD SUAM n. 659 R.G' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/6665/P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 699' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 19' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2094' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 034' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 636' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 873' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 10040' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 11922' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 78' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1190/DG di aggiudicazione' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1069' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 240' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 71/2020' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 5131' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 5832' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 830' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera ANAC n. 1121' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione ANAC n. 157' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM 2 dicembre 2016' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. Reg. Generale 3805' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 9166' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Atto n. 10730' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 702' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 734' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 286' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 344' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2022/R.SAP/0097' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 423' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n.1671' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 180' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD a contrarre' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 148' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. CDG-0513657-Int.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 248' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2057 R.G.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DPCM' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 565' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 90-2022' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 444' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1594' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 508' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 523 R.U.A.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 067' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 4327' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1339' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 257' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 288' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DPP n. 32' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Det n. 7' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1976' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1149' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 188' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 974' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 1322' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 1523' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 155' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Det n. 1511' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 685 R.U.A.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1059' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. TER 22/142' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 052' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 772' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 7' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 950' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 196/54467' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM del 02/12/2016' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 493' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 350' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 196' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. A/D/1114/P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD Prot. A/D/1672/P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DDG n. 465' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 148' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 00000085' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1036' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 725' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 378' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 5077/2022' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD prot. n. 0011660-P' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 136' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 544' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 615' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 932' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 653' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 166' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 387' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 1085' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. TER 22/041' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 78645' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2389' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DM del 02/12/2016' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera del Consiglio di Amministrazione n. SCA-LC-361' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Deliberazione n. 824' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD A/D/3442/p' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 690' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD a contrarre' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 3336' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 241' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 246' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 17772' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 840' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 921' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD Prot. n. CDG-0513635-Int.' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 20993' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 06' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 2022/12/0019' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 376' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Delibera n. 22AU032' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DGC n. 946' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 841' is not in the correct format. Use DD/MM/YYYY.
# Error: 'Decreto n. 236' is not in the correct format. Use DD/MM/YYYY.
# Error: 'DD n. 141' is not in the correct format. Use DD/MM/YYYY.
#         case_id                                 complementary_info  \
# 0    219-630869  Atto esito di gara: Provvedimento DG n. 36 del...
# 1    153-437453  1) il bando di gara, il fac-simile modulo di o...
# 2    243-697432  Determinazione Agg.ne AD di Marche Multiserviz...
# 3    091-251847  a) deliberazione a contrattare prot. n. 27083 ...
# 4    045-117742  Deliberazione di indizione della procedura ape...
# ..          ...                                                ...
# 297  162-460604  CIG 93635451C7\nRUP: avv. Francesca Leone, dip...
# 298  061-161865  IL VALORE STIMATO E' AL NETTO DI IVA E DEGLI O...
# 299  025-060373  CIG 9046840889\nTermine per ottenere chiarimen...
# 300  135-381854  Il Disciplinare di Gara, che forma parte integ...
# 301  164-467269  Appalto indetto con Determinazione della Respo...
#
#                    event        date label note
# 0              DDG n. 36  31/05/2022
# 1             DGC n. 567  07/07/2022
# 2          DD n. 73/2022  28/10/2022
# 3      Delibera n. 27083  28/04/2022
# 4         Delibera n. 10  23/02/2022
# ..                   ...         ...   ...  ...
# 297  Delibera n. 22AU032  09/08/2022
# 298           DGC n. 946  21/03/2022
# 299       Decreto n. 841  31/01/2022
# 300       Decreto n. 236  08/07/2022
# 301            DD n. 141  17/12/2021
#
# [302 rows x 6 columns]

# %%
if EXTRACT_EVALUATION_SAMPLE:
    idx_sample = df_evaluation.case_id.tolist()
    idx_sample = list(set(idx_sample))
    idx_sample = random.sample(idx_sample, 100)
    idx_sample = pd.DataFrame(idx_sample, columns=["case_id"])
    idx_sample.to_csv(f'{OUTPUT_DIR}/evaluation/idx_sample.csv', index=False)

idx_sample = pd.read_csv(f'{OUTPUT_DIR}/evaluation/idx_sample.csv').case_id
df_evaluation = df_evaluation[df_evaluation.case_id.isin(idx_sample)]
df_evaluation
# Out:
#         case_id                                 complementary_info  \
# 1    153-437453  1) il bando di gara, il fac-simile modulo di o...
# 2    243-697432  Determinazione Agg.ne AD di Marche Multiserviz...
# 4    045-117742  Deliberazione di indizione della procedura ape...
# 6    135-384701  Determinazione di contrarre n. A/D/3504 del 07...
# 12   221-636448  La “Disposizione a Contrarre” per la presente ...
# ..          ...                                                ...
# 288  020-050569  Ulteriori informazioni sulla procedura di aggi...
# 292  148-423793  a) A pena di irregolarità non sanabile delle o...
# 297  162-460604  CIG 93635451C7\nRUP: avv. Francesca Leone, dip...
# 298  061-161865  IL VALORE STIMATO E' AL NETTO DI IVA E DEGLI O...
# 299  025-060373  CIG 9046840889\nTermine per ottenere chiarimen...
#
#                             event        date label note
# 1                      DGC n. 567  07/07/2022
# 2                   DD n. 73/2022  28/10/2022
# 4                  Delibera n. 10  23/02/2022
# 6                  DD n. A/D/3504  07/07/2022
# 12       Disposizione a Contrarre  02/09/2022
# ..                            ...         ...   ...  ...
# 288                     DD n. 246  24/11/2021
# 292  DD Prot. n. CDG-0513635-Int.  22/07/2022
# 297           Delibera n. 22AU032  09/08/2022
# 298                    DGC n. 946  21/03/2022
# 299                Decreto n. 841  31/01/2022
#
# [115 rows x 6 columns]

# %%
with pd.ExcelWriter(f'{OUTPUT_DIR}/evaluation/TED_annotation.xlsx') as writer:
        df_evaluation.to_excel(writer, sheet_name='event_detection')
